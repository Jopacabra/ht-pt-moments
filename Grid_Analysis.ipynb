# %%
import os
import numpy as np
import pandas as pd
import grid_reader as gr
import medium_integral as mi
import ipympl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Open grid file
Random_grid_data, Random_grid_width, Random_NT = gr.load_grid_file('Random.dat')

# Interpolate temperatures
Random_temp_func = gr.interpolate_temp_grid(Random_grid_data, Random_grid_width, Random_NT)

# Interpolate x velocities
Random_vel_x_func = gr.interpolate_x_vel_grid(Random_grid_data, Random_grid_width, Random_NT)

# Interpolate y velocities
Random_vel_y_func = gr.interpolate_y_vel_grid(Random_grid_data, Random_grid_width, Random_NT)
# Out:
# Interpolating temp grid data ...
# Interpolating x vel. grid data ...
# Interpolating y vel. grid data ...

# %%
# Open grid file
Seeded_grid_data, Seeded_grid_width, Seeded_NT = gr.load_grid_file('Seeded.dat')

# Interpolate temperatures
Seeded_temp_func = gr.interpolate_temp_grid(Seeded_grid_data, Seeded_grid_width, Seeded_NT)

# Interpolate x velocities
Seeded_vel_x_func = gr.interpolate_x_vel_grid(Seeded_grid_data, Seeded_grid_width, Seeded_NT)

# Interpolate y velocities
Seeded_vel_y_func = gr.interpolate_y_vel_grid(Seeded_grid_data, Seeded_grid_width, Seeded_NT)
# Out:
# Interpolating temp grid data ...
# Interpolating x vel. grid data ...
# Interpolating y vel. grid data ...

# %%
# Open grid file
Event_6_grid_data, Event_6_grid_width, Event_6_NT = gr.load_grid_file('Event_6.dat')

# Interpolate temperatures
Event_6_temp_func = gr.interpolate_temp_grid(Event_6_grid_data, Event_6_grid_width, Event_6_NT)

# Interpolate x velocities
Event_6_vel_x_func = gr.interpolate_x_vel_grid(Event_6_grid_data, Event_6_grid_width, Event_6_NT)

# Interpolate y velocities
Event_6_vel_y_func = gr.interpolate_y_vel_grid(Event_6_grid_data, Event_6_grid_width, Event_6_NT)
# Out:
# Loading grid data from file ...
# Calculating grid parameters ...
# Interpolating temp grid data ...
# Interpolating x vel. grid data ...
# Interpolating y vel. grid data ...

# %%
# Open grid file
Event_7_grid_data, Event_7_grid_width, Event_7_NT = gr.load_grid_file('Event_7.dat')

# Interpolate temperatures
Event_7_temp_func = gr.interpolate_temp_grid(Event_7_grid_data, Event_7_grid_width, Event_7_NT)

# Interpolate x velocities
Event_7_vel_x_func = gr.interpolate_x_vel_grid(Event_7_grid_data, Event_7_grid_width, Event_7_NT)

# Interpolate y velocities
Event_7_vel_y_func = gr.interpolate_y_vel_grid(Event_7_grid_data, Event_7_grid_width, Event_7_NT)
# Out:
# Loading grid data from file ...
# Calculating grid parameters ...
# Interpolating temp grid data ...
# Interpolating x vel. grid data ...
# Interpolating y vel. grid data ...

# %%
# Open grid file
Event_8_grid_data, Event_8_grid_width, Event_8_NT = gr.load_grid_file('Event_8.dat')

# Interpolate temperatures
Event_8_temp_func = gr.interpolate_temp_grid(Event_8_grid_data, Event_8_grid_width, Event_8_NT)

# Interpolate x velocities
Event_8_vel_x_func = gr.interpolate_x_vel_grid(Event_8_grid_data, Event_8_grid_width, Event_8_NT)

# Interpolate y velocities
Event_8_vel_y_func = gr.interpolate_y_vel_grid(Event_8_grid_data, Event_8_grid_width, Event_8_NT)
# Out:
# Loading grid data from file ...
# Calculating grid parameters ...
# Interpolating temp grid data ...
# Interpolating x vel. grid data ...
# Interpolating y vel. grid data ...

# %%
# Open grid file
Event_9_grid_data, Event_9_grid_width, Event_9_NT = gr.load_grid_file('Event_9.dat')

# Interpolate temperatures
Event_9_temp_func = gr.interpolate_temp_grid(Event_9_grid_data, Event_9_grid_width, Event_9_NT)

# Interpolate x velocities
Event_9_vel_x_func = gr.interpolate_x_vel_grid(Event_9_grid_data, Event_9_grid_width, Event_9_NT)

# Interpolate y velocities
Event_9_vel_y_func = gr.interpolate_y_vel_grid(Event_9_grid_data, Event_9_grid_width, Event_9_NT)
# Out:
# Loading grid data from file ...
# Calculating grid parameters ...
# Interpolating temp grid data ...
# Interpolating x vel. grid data ...
# Interpolating y vel. grid data ...

# %%
# Open grid file
Event_10_grid_data, Event_10_grid_width, Event_10_NT = gr.load_grid_file('Event_10.dat')

# Interpolate temperatures
Event_10_temp_func = gr.interpolate_temp_grid(Event_10_grid_data, Event_10_grid_width, Event_10_NT)

# Interpolate x velocities
Event_10_vel_x_func = gr.interpolate_x_vel_grid(Event_10_grid_data, Event_10_grid_width, Event_10_NT)

# Interpolate y velocities
Event_10_vel_y_func = gr.interpolate_y_vel_grid(Event_10_grid_data, Event_10_grid_width, Event_10_NT)
# Out:
# Loading grid data from file ...
# Calculating grid parameters ...
# Interpolating temp grid data ...
# Interpolating x vel. grid data ...
# Interpolating y vel. grid data ...

# %%
gr.qgp_plot(Event_6_temp_func, Event_6_vel_x_func, Event_6_vel_y_func, 0.5)
gr.qgp_plot(Event_7_temp_func, Event_7_vel_x_func, Event_7_vel_y_func, 0.5)
gr.qgp_plot(Event_8_temp_func, Event_8_vel_x_func, Event_8_vel_y_func, 0.5)

# %%
# Get and print minimum and maximum x & y velocities directly from the grid data.
# Checking this means the problem is not in your interpolation.
print('Event_6 x min, max: ' + str(np.amin(Event_6_grid_data['xvel'].to_numpy())) + ', ' + str(np.amax(Event_6_grid_data['xvel'].to_numpy())))
print('Event_6 y min, max: ' + str(np.amin(Event_6_grid_data['yvel'].to_numpy())) + ', ' + str(np.amax(Event_6_grid_data['yvel'].to_numpy())))
print('Event_7 x min, max: ' + str(np.amin(Event_7_grid_data['xvel'].to_numpy())) + ', ' + str(np.amax(Event_7_grid_data['xvel'].to_numpy())))
print('Event_7 y min, max: ' + str(np.amin(Event_7_grid_data['yvel'].to_numpy())) + ', ' + str(np.amax(Event_7_grid_data['yvel'].to_numpy())))
print('Event_8 x min, max: ' + str(np.amin(Event_8_grid_data['xvel'].to_numpy())) + ', ' + str(np.amax(Event_8_grid_data['xvel'].to_numpy())))
print('Event_8 y min, max: ' + str(np.amin(Event_8_grid_data['yvel'].to_numpy())) + ', ' + str(np.amax(Event_8_grid_data['yvel'].to_numpy())))
# Out:
# Event_6 x min, max: 0.0, 0.99999997
# Event_6 y min, max: -0.99999978, 0.99999847
# Event_7 x min, max: 0.0, 0.99999987
# Event_7 y min, max: 0.0, 0.99999935
# Event_8 x min, max: 0.0, 0.99999973
# Event_8 y min, max: 0.0, 0.99999986

# %%
gr.qgp_plot(Event_9_temp_func, Event_9_vel_x_func, Event_9_vel_y_func, 0.5)
gr.qgp_plot(Event_9_temp_func, Event_9_vel_x_func, Event_9_vel_y_func, 1)
gr.qgp_plot(Event_9_temp_func, Event_9_vel_x_func, Event_9_vel_y_func, 5)

# %%
print('Event_9 x min, max: ' + str(np.amin(Event_9_grid_data['xvel'].to_numpy())) + ', ' + str(np.amax(Event_9_grid_data['xvel'].to_numpy())))
print('Event_9 y min, max: ' + str(np.amin(Event_9_grid_data['yvel'].to_numpy())) + ', ' + str(np.amax(Event_9_grid_data['yvel'].to_numpy())))
# Out:
# Event_9 x min, max: -0.99999913, 0.99999373
# Event_9 y min, max: -0.99999995, 0.99999908

# %%
plt.plot(np.arange(-7.5,7.5,0.1), np.sqrt(Event_9_vel_x_func(0.5, np.arange(-7.5,7.5,0.1), 0)**2 + Event_9_vel_y_func(0.5, np.arange(-7.5,7.5,0.1), 0)**2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_21247/2883468838.py in <module>
# ----> 1 plt.plot(np.arange(-7.5,7.5,0.1), np.sqrt(Event_9_vel_x_func(0.5, np.arange(-7.5,7.5,0.1), 0)**2 + Event_9_vel_y_func(0.5, np.arange(-7.5,7.5,0.1), 0)**2))
#
# TypeError: __call__() takes from 2 to 3 positional arguments but 4 were given

# %%
print('Event_10 x min, max: ' + str(np.amin(Event_10_grid_data['xvel'].to_numpy())) + ', ' + str(np.amax(Event_10_grid_data['xvel'].to_numpy())))
print('Event_10 y min, max: ' + str(np.amin(Event_10_grid_data['yvel'].to_numpy())) + ', ' + str(np.amax(Event_10_grid_data['yvel'].to_numpy())))

gr.qgp_plot(Event_10_temp_func, Event_10_vel_x_func, Event_10_vel_y_func, 0.5)
gr.qgp_plot(Event_10_temp_func, Event_10_vel_x_func, Event_10_vel_y_func, 1)
gr.qgp_plot(Event_10_temp_func, Event_10_vel_x_func, Event_10_vel_y_func, 5)
# Out:
# Event_10 x min, max: 0.0, 0.99999958
# Event_10 y min, max: 0.0, 0.99999961
